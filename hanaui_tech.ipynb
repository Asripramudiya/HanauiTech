# %%
import pymongo
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
myclient = pymongo.MongoClient("mongodb://hanaui:hanauitech@hanaui-shard-00-00.ezxck.mongodb.net:27017,hanaui-shard-00-01.ezxck.mongodb.net:27017,hanaui-shard-00-02.ezxck.mongodb.net:27017/?ssl=true&replicaSet=atlas-hiu18k-shard-0&authSource=admin&retryWrites=true&w=majority")
db = myclient

# %%
query = myclient.list_database_names()
print(query)
# Out:
# ['University', 'admin', 'local']

# %%
db = myclient["University"]
db.list_collection_names()
# Out:
# ['Student', 'Rank', 'Univ']

# %%
col1 = db.Univ

# %%
col2 = db.Rank

# %%
rec1 = col1.find()
res1 = list(rec1)

# %%
df1 = pd.DataFrame(res1)
df1.head()
# Out:
#                         _id                                    university  \
# 0  62d249c474ea1ace4c1a2ae3  Massachusetts Institute of Technology (MIT)
# 1  62d249c474ea1ace4c1a2ae4                           Stanford University
# 2  62d249c474ea1ace4c1a2ae5                            Harvard University
# 3  62d249c474ea1ace4c1a2ae6                       University of Cambridge
# 4  62d249c474ea1ace4c1a2ae7  California Institute of Technology (Caltech)
#
#                                                 link         country  \
# 0  https://www.topuniversities.com/universities/m...   United States
# 1  https://www.topuniversities.com/universities/s...   United States
# 2  https://www.topuniversities.com/universities/h...   United States
# 3  https://www.topuniversities.com/universities/u...  United Kingdom
# 4  https://www.topuniversities.com/universities/c...   United States
#
#         city         region  \
# 0  Cambridge  North America
# 1   Stanford  North America
# ...

# %%
rec2 = col2.find()
res2 = list(rec2)

# %%
df2 = pd.DataFrame(res2)
df2.head()
# Out:
#                         _id                   univ_id  year  rank_display  \
# 0  62d24ec974ea1ace4c1a4437  62d249c474ea1ace4c1a2ae3  2017           1.0
# 1  62d24ec974ea1ace4c1a4438  62d249c474ea1ace4c1a2ae4  2017           2.0
# 2  62d24ec974ea1ace4c1a4439  62d249c474ea1ace4c1a2ae5  2017           3.0
# 3  62d24ec974ea1ace4c1a443a  62d249c474ea1ace4c1a2ae6  2017           4.0
# 4  62d24ec974ea1ace4c1a443b  62d249c474ea1ace4c1a2ae7  2017           5.0
#
#   score research_output
# 0   100       Very High
# 1  98.7       Very High
# 2  98.3       Very High
# 3  97.2       Very high
# 4  96.9       Very High

# %%
df_list = [df1, df2]
pd.concat(df_list)
# Out:
#                            _id                                    university  \
# 0     62d249c474ea1ace4c1a2ae3  Massachusetts Institute of Technology (MIT)
# 1     62d249c474ea1ace4c1a2ae4                           Stanford University
# 2     62d249c474ea1ace4c1a2ae5                            Harvard University
# 3     62d249c474ea1ace4c1a2ae6                       University of Cambridge
# 4     62d249c474ea1ace4c1a2ae7  California Institute of Technology (Caltech)
# ...                        ...                                           ...
# 6477  62d24ecb74ea1ace4c1a5d84                                           NaN
# 6478  62d24ecb74ea1ace4c1a5d85                                           NaN
# 6479  62d24ecb74ea1ace4c1a5d86                                           NaN
# 6480  62d24ecb74ea1ace4c1a5d87                                           NaN
# 6481  62d24ecb74ea1ace4c1a5d88                                           NaN
#
# ...

# %%
df=pd.concat(df_list, axis=1)

# %%
df
# Out:
#                            _id                                    university  \
# 0     62d249c474ea1ace4c1a2ae3  Massachusetts Institute of Technology (MIT)
# 1     62d249c474ea1ace4c1a2ae4                           Stanford University
# 2     62d249c474ea1ace4c1a2ae5                            Harvard University
# 3     62d249c474ea1ace4c1a2ae6                       University of Cambridge
# 4     62d249c474ea1ace4c1a2ae7  California Institute of Technology (Caltech)
# ...                        ...                                           ...
# 6477  62d249c874ea1ace4c1a4430                              Universit�� de T
# 6478  62d249c874ea1ace4c1a4431                     Universit�� de Tunis El M
# 6479  62d249c874ea1ace4c1a4432                            Yarmouk University
# 6480  62d249c874ea1ace4c1a4433                   Yildiz Technical University
# 6481  62d249c874ea1ace4c1a4434                            Zagazig University
#
# ...

# %%
df.shape
# Out:
# (6482, 15)

# %%
df.year.unique()
# Out:
# array([2017, 2018, 2019, 2020, 2021, 2022], dtype=int64)

# %%
df_th = df[(df["year"] <2020)].index
df = df.drop(df_th)

# %%
df.shape
# Out:
# (3554, 15)

# %%
df.year.unique()
# Out:
# array([2020, 2021, 2022], dtype=int64)

# %%
df.isnull().sum()
# Out:
# _id                   0
# university            0
# link                  0
# country               0
# city                121
# region                0
# logo                  0
# type                  8
# faculty_count        36
# _id                   0
# univ_id               0
# year                  0
# rank_display         28
# score              2046
# research_output       2
# dtype: int64

# %%
miss = round(df.isnull().sum())
pd.DataFrame(miss[miss>0])
# Out:
#                     0
# city              121
# type                8
# faculty_count      36
# rank_display       28
# score            2046
# research_output     2

# %%
print(len(df[df.isnull().sum(axis=1) > 2]))
drop_index = df[df.isnull().sum(axis=1) > 2].index.tolist()
df.drop(drop_index, inplace=True)
# Out:
# 14

# %%
df.shape
# Out:
# (3540, 15)

# %%
df.drop(["link","logo","score"], axis=1, inplace=True)

# %%
df.shape
# Out:
# (3540, 12)

# %%
print('Jumlah negara dengan peringkat universitas: ',df['country'].nunique())
# Out:
# Jumlah negara dengan peringkat universitas:  97

# %%
uni_df = df['university'].value_counts()

fig, ax = plt.subplots(figsize=(10,20))

sns.countplot(data=df, y='country', order=df.country.value_counts().index);
ax.bar_label(ax.containers[0])
plt.xlabel('Jumlah universitas', fontsize=12)
plt.ylabel('Country', fontsize=12)
plt.title('Negara yang memiliki Universitas yang diperingkat', fontsize=14);

# %%
urut_df = df.sort_values(by='rank_display').drop_duplicates('university')
urut_df = pd.DataFrame(urut_df['city'].value_counts()[:10])

# %%
fig, ax = plt.subplots(figsize=(10,10))
sns.barplot(data=urut_df, y='city', x=urut_df.index)
plt.xticks(rotation=90);

ax.bar_label(ax.containers[0])

ax.set_xlabel('Nama Kota', fontsize=13);
fig.suptitle('Distribusi universitas di seluruh kota', fontsize=15);
